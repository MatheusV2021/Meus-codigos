# %%
# ETE PORTO DIGITAL
# DISCIPLINA: LPC
# PROFESSOR: CLOVES ROCHA
# ESTUDANTE: MATHEUS VINNYCIUS VASCONCELOS DE SANTANA

# [ATV 2 e 3] Exercícios e Desafios 

# 1. Faça um CÓDIGO que mostre a mensagem "Olá ETE PORTO DIGITAL!" na tela.

c = "Olá ETE PORTO DIGITAL!"
print(c)

# %%
# 2. Faça um CÓDIGO que peça um número e então mostre a mensagem O número informado foi [número].

num = input("Digite um numero:")
print('o numero digitado foi', num)
# Out:
# Digite um numero:5
# o numero digitado foi 5

# %%
# 3. Faça um CÓDIGO que peça dois números e imprima a soma.

num1 = int(input("digite um numero:"))
num2 = int(input("digite mais um numero:"))

soma = num1 + num2 

print(soma)

# %%
# 4. Faça um CÓDIGO que peça as 4 notas bimestrais e mostre a média final.

nota1 = int(input("digita a nota 1:"))
nota2 = int(input("digita a nota 2:"))
nota3 = int(input("digita a nota 3:"))
nota4 = int(input("digita a nota 4:"))

media = (nota1 + nota2 + nota3 + nota4)/4


print(media)
# Out:
# digita a nota 1:8
# digita a nota 2:4
# digita a nota 3:9
# digita a nota 4:6
# 6.75

# %%
# 5. Faça um CÓDIGO que converta metros para centímetros.

metros = int(input("digite uma quantidade de metros: "))
centimetros = (metros * 100)
print("esses são os metros que você digitou convertidos em centimetros:", centimetros)
# Out:
# digite uma quantidade de metros: 5
# esses são os metros que você digitou convertidos em centimetros: 500

# %%
# 6. Faça um CÓDIGO que peça o raio de um círculo, calcule e mostre sua área.

pi = 3.14
r  = float(input("Digite o raio do Circulo em metros:  "))
g =  pi * (r * r)
print("A área do circulo é:",g,'m²')

# %%
# 7. Faça um CÓDIGO que calcule a área de um quadrado, em seguida mostre o dobro desta área para o usuário.

a = float(input("Informe o lado do quadrado"))
b = a * a
c = area * 2

print("a área é:",b, "e o dobro é: ", c)

# %%
# 8. Faça um CÓDIGO que pergunte quanto você ganha por hora e o número de horas trabalhadas no mês. Calcule e mostre o total do seu salário no referido mês.

h = int(input("Quanto voce ganha por hora: "))
m = int(input("Quantas horas você trabalhou durante o mês: "))

print("Salario total esse mês R$",(h*m))

# %%
# 9. Faça um CÓDIGO que peça um valor e mostre na tela se o valor é positivo ou negativo.

num = int(input("digite um numero positivo ou negativo"))
if num < 0:
  print("o numero é negativo")
else:
  print("o numero é positivo")

# %%
# 10. Faça um CÓDIGO que verifique se uma letra digitada é "F" ou "M". Conforme a letra escrever: F - Feminino, M - Masculino, Sexo Inválido.

a=input('m ou f: ')

if a == 'm':
    print('Masculina')
else:
    if a == 'f':
          print('Feminina')
    else:
        print('Sexo invalido')
